# %% [markdown]
# ### EDA

# %% [markdown]
# The following cell imports the needed libraries.

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import imagesize
import csv

# %%
try:
    if not os.path.exists('video_data'):
        os.makedirs('video_data')
except OSError:
    print('Error creating data directory.')
    
# path = os.path('video_data')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       4 except OSError:
#       5     print('Error creating data directory.')
# ----> 7 path = os.path('video_data')
#
# TypeError: 'module' object is not callable

# %%
def video_to_image(filename):
    capture = cv2.VideoCapture(filename)
    images_created = 0
    currentFrame = 0
    frameSkip = 20 # Save one frame every 10 frames
#     resizeWidth, resizeHeight = 224, 224  # Desired width and height for CNN

    while True:
        ret, frame = capture.read()
        # print(ret)

        # Break the loop if no frame is captured
        if not ret:
            break

        # Only save every 'frameSkip'-th frame
        if currentFrame % frameSkip == 0:
            # Resize the frame
#             resized_frame = cv2.resize(frame, (resizeWidth, resizeHeight))

            # Save the resized frame
            name = f'video_data/{filename.split("/")[-1]}_frame{currentFrame}.jpg'
#             name = 'video_data/video_dataframe.jpg'
        
            print('Creating file:', name)
                
            cv2.imwrite(name, frame)
            images_created += 1

        currentFrame += 1

    print(f'Images created for {filename}: {images_created}')
    capture.release()
    cv2.destroyAllWindows()

# %%
import os

# directory = '../../../ai_club/team_13_2024-25/VIPR/Data/Raw Videos'
directory = '/data/ai_club/team_13_2024-25/VIPR/Data/Raw Videos'
for video_file_name in os.listdir(directory):
    # Construct the full file path
    video_path = os.path.join(directory, video_file_name)
    
    # Pass the full path to the function
    video_to_image(video_path)
# Out:
# Creating file: video_data/media8.mp4_frame0.jpg
# Creating file: video_data/media8.mp4_frame20.jpg
# Creating file: video_data/media8.mp4_frame40.jpg
# Creating file: video_data/media8.mp4_frame60.jpg
# Creating file: video_data/media8.mp4_frame80.jpg
# Creating file: video_data/media8.mp4_frame100.jpg
# Creating file: video_data/media8.mp4_frame120.jpg
# Creating file: video_data/media8.mp4_frame140.jpg
# Creating file: video_data/media8.mp4_frame160.jpg
# Creating file: video_data/media8.mp4_frame180.jpg
# Creating file: video_data/media8.mp4_frame200.jpg
# Creating file: video_data/media8.mp4_frame220.jpg
# Creating file: video_data/media8.mp4_frame240.jpg
# Creating file: video_data/media8.mp4_frame260.jpg
# Images created for /data/ai_club/team_13_2024-25/VIPR/Data/Raw Videos/media8.mp4: 14
# Creating file: video_data/media3.MP4_frame0.jpg
# Creating file: video_data/media3.MP4_frame20.jpg
# Creating file: video_data/media3.MP4_frame40.jpg
# Images created for /data/ai_club/team_13_2024-25/VIPR/Data/Raw Videos/media3.MP4: 3
# Creating file: video_data/media2.mp4_frame0.jpg
# Creating file: video_data/media2.mp4_frame20.jpg
# Creating file: video_data/media2.mp4_frame40.jpg
# Creating file: video_data/media2.mp4_frame60.jpg
# Creating file: video_data/media2.mp4_frame80.jpg
# Images created for /data/ai_club/team_13_2024-25/VIPR/Data/Raw Videos/media2.mp4: 5
# Creating file: video_data/media10.mp4_frame0.jpg
# Creating file: video_data/media10.mp4_frame20.jpg
# Creating file: video_data/media10.mp4_frame40.jpg
# Creating file: video_data/media10.mp4_frame60.jpg
# Creating file: video_data/media10.mp4_frame80.jpg
# Creating file: video_data/media10.mp4_frame100.jpg
# Images created for /data/ai_club/team_13_2024-25/VIPR/Data/Raw Videos/media10.mp4: 6
# Creating file: video_data/media6.mp4_frame0.jpg
# Creating file: video_data/media6.mp4_frame20.jpg
# Creating file: video_data/media6.mp4_frame40.jpg
# Creating file: video_data/media6.mp4_frame60.jpg
# Creating file: video_data/media6.mp4_frame80.jpg
# Images created for /data/ai_club/team_13_2024-25/VIPR/Data/Raw Videos/media6.mp4: 5
# Creating file: video_data/media4.MP4_frame0.jpg
# Creating file: video_data/media4.MP4_frame20.jpg
# Creating file: video_data/media4.MP4_frame40.jpg
# Images created for /data/ai_club/team_13_2024-25/VIPR/Data/Raw Videos/media4.MP4: 3
# Creating file: video_data/media9.mp4_frame0.jpg
# Creating file: video_data/media9.mp4_frame20.jpg
# Creating file: video_data/media9.mp4_frame40.jpg
# Creating file: video_data/media9.mp4_frame60.jpg
# Creating file: video_data/media9.mp4_frame80.jpg
# Creating file: video_data/media9.mp4_frame100.jpg
# Creating file: video_data/media9.mp4_frame120.jpg
# Creating file: video_data/media9.mp4_frame140.jpg
# Creating file: video_data/media9.mp4_frame160.jpg
# Creating file: video_data/media9.mp4_frame180.jpg
# Creating file: video_data/media9.mp4_frame200.jpg
# Creating file: video_data/media9.mp4_frame220.jpg
# Images created for /data/ai_club/team_13_2024-25/VIPR/Data/Raw Videos/media9.mp4: 12

# %%
df = []
rootDir = './video_data'
for dirName,subdirList, fileList in os.walk(rootDir):
    for fname in fileList:
         df = pd.read_csv(fname)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 5
#       3 for dirName,subdirList, fileList in os.walk(rootDir):
#       4     for fname in fileList:
# ----> 5          df = pd.read_csv(fname)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'media8.mp4_frame0.jpg'

# %%
os.path.exists('./video_data')
# Out:
# True

# %%
# imageDir = './video_data'
filename = 'video_data/media10.mp4_frame0.jpg'
image = cv2.imread(filename)
# np.toArray(filename)
cv2.imshow('image',image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[49], line 5
#       3 image = cv2.imread(filename)
#       4 # np.toArray(filename)
# ----> 5 cv2.imshow('image',image)
#       6 cv2.waitKey(0)
#       7 cv2.destroyAllWindows()
#
# error: OpenCV(4.5.4) ./modules/highgui/src/window_gtk.cpp:652: error: (-2:Unspecified error) GTK backend is not available in function 'cvInitSystem'

# %%
# Python program to read 

# image using matplotlib
 
# importing matplotlib modules

import matplotlib.image as mpimg

import matplotlib.pyplot as plt
 
# Read Images
filename = 'video_data/media10.mp4_frame0.jpg'

img = mpimg.imread(filename)
 
# Output Images

plt.imshow(img)
